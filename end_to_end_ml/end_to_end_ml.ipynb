# %%
# %pip install numpy
import numpy as np
# Out:
# Requirement already satisfied: numpy in /Users/jomman/jupyter_envs/jupyter_venv/lib/python3.9/site-packages (2.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_csv("placement.csv")

# %%
df
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.2 KB

# %%
df.iloc[:, 1:]
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]

# %%
df = df.iloc[:, 1:]

# %%
df
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
# %pip install matplotlib
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: matplotlib in /Users/jomman/jupyter_envs/jupyter_venv/lib/python3.9/site-packages (3.9.4)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/jomman/jupyter_envs/jupyter_venv/lib/python3.9/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/jomman/jupyter_envs/jupyter_venv/lib/python3.9/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/jomman/jupyter_envs/jupyter_venv/lib/python3.9/site-packages (from matplotlib) (4.60.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/jomman/jupyter_envs/jupyter_venv/lib/python3.9/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in /Users/jomman/jupyter_envs/jupyter_venv/lib/python3.9/site-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /Users/jomman/jupyter_envs/jupyter_venv/lib/python3.9/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/jomman/jupyter_envs/jupyter_venv/lib/python3.9/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/jomman/jupyter_envs/jupyter_venv/lib/python3.9/site-packages (from matplotlib) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/jomman/jupyter_envs/jupyter_venv/lib/python3.9/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/jomman/jupyter_envs/jupyter_venv/lib/python3.9/site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in /Users/jomman/jupyter_envs/jupyter_venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.23.0)
# Requirement already satisfied: six>=1.5 in /Users/jomman/jupyter_envs/jupyter_venv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
plt.scatter(df['cgpa'], df['iq'])

# %%
plt.scatter(df['cgpa'], df['iq'], c=df['placement'])

# %%
x = df.iloc[:, 0:2]
y = df.iloc[:, -1]

# %%
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
y.shape
# Out:
# (100,)

# %%
y.shape
# Out:
# (100,)

# %%
from sklearn.model_selection import train_test_split

# %%
train_test_split(x, y, test_size = 0.1)
# Out:
# [    cgpa     iq
#  65   8.1  166.0
#  6    5.7  143.0
#  58   8.0   79.0
#  81   5.4  107.0
#  36   5.7  140.0
#  ..   ...    ...
#  88   4.4  149.0
#  87   5.7  132.0
#  38   6.5  160.0
#  63   6.3  128.0
#  17   3.3  183.0
#
#  [90 rows x 2 columns],
#      cgpa     iq
#  67   5.0  118.0
#  76   4.9  155.0
#  98   6.3  103.0
#  0    6.8  123.0
#  73   4.9   61.0
#  47   5.2  161.0
#  89   4.9  151.0
#  33   6.0  149.0
#  80   4.9  196.0
#  1    5.9  106.0,
#  65    1
#  6     0
#  58    1
#  81    0
#  36    0
#       ..
#  88    0
#  87    1
#  38    1
#  63    1
#  17    0
#  Name: placement, Length: 90, dtype: int64,
#  67    0
#  76    0
#  98    1
#  0     1
#  73    0
#  47    0
#  89    0
#  33    0
#  80    0
#  1     0
#  Name: placement, dtype: int64]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1)

# %%
x_train
# Out:
#     cgpa     iq
# 62   6.0  102.0
# 93   6.8  112.0
# 2    5.3  121.0
# 80   4.9  196.0
# 45   6.0   66.0
# ..   ...    ...
# 96   4.4   42.0
# 18   4.0  100.0
# 50   3.5  233.0
# 7    5.0   63.0
# 19   5.2  132.0
#
# [90 rows x 2 columns]

# %%
x_test
# Out:
#     cgpa     iq
# 47   5.2  161.0
# 16   5.2  224.0
# 66   6.9   96.0
# 35   6.8   90.0
# 41   5.4  114.0
# 13   6.4  116.0
# 3    7.4  132.0
# 37   8.1  149.0
# 46   5.3  114.0
# 56   6.1   65.0

# %%
y_train
# Out:
# 62    0
# 93    1
# 2     0
# 80    0
# 45    1
#      ..
# 96    0
# 18    0
# 50    0
# 7     0
# 19    0
# Name: placement, Length: 90, dtype: int64

# %%
y_test
# Out:
# 47    0
# 16    0
# 66    1
# 35    1
# 41    0
# 13    1
# 3     1
# 37    1
# 46    0
# 56    0
# Name: placement, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit_transform(x_train)
# Out:
# array([[ 0.03571986, -0.53968959],
#        [ 0.73080904, -0.2863142 ],
#        [-0.57248317, -0.05827634],
#        [-0.92002776,  1.84203913],
#        [ 0.03571986, -1.45184102],
#        [-1.3544585 ,  0.65117477],
#        [ 0.73080904,  0.44847445],
#        [ 0.64392289,  0.77786247],
#        [-0.48559702,  0.29644921],
#        [ 0.38326445,  0.44847445],
#        [ 1.42589822, -0.86907761],
#        [-1.09380006, -0.91975269],
#        [ 0.55703675,  0.37246183],
#        [ 0.03571986, -1.98392935],
#        [-0.48559702, -0.4130019 ],
#        [ 0.90458134,  0.39779937],
#        [ 0.12260601, -0.51435205],
#        [-0.74625547,  0.11908644],
#        [-0.22493858,  0.49914953],
#        [ 0.99146748, -1.90791673],
#        [ 1.16523978, -0.94509023],
#        [-1.09380006, -0.05827634],
#        [ 0.81769519,  0.39779937],
#        [ 0.03571986,  0.65117477],
#        [ 1.16523978,  0.34712429],
#        [-0.48559702,  0.39779937],
#        [ 1.33901207,  0.87921262],
#        [ 0.4701506 , -2.18662967],
#        [ 0.90458134, -0.2863142 ],
#        [ 0.4701506 ,  0.9298877 ],
#        [-0.05116629, -0.43833944],
#        [-1.00691391,  0.44847445],
#        [-0.65936932, -0.84374007],
#        [ 0.12260601, -1.07177793],
#        [-1.00691391,  1.15792556],
#        [ 0.2963783 ,  0.0937489 ],
#        [ 1.42589822,  0.11908644],
#        [ 0.03571986,  0.01773628],
#        [-1.78888924, -0.36232682],
#        [ 0.81769519,  0.37246183],
#        [-0.13805243,  1.08191294],
#        [-0.13805243,  0.47381199],
#        [ 1.16523978, -1.85724165],
#        [-0.92002776, -1.57852872],
#        [ 0.4701506 ,  0.16976152],
#        [-0.74625547,  1.33528834],
#        [ 0.4701506 , -0.84374007],
#        [-0.92002776,  0.70184985],
#        [-0.22493858,  0.22043659],
#        [ 2.03410125,  1.13258802],
#        [ 1.33901207, -1.57852872],
#        [-1.70200309, -1.22380316],
#        [ 0.12260601,  0.82853755],
#        [ 0.20949216, -0.26097666],
#        [ 0.90458134, -1.5025161 ],
#        [-1.44134465,  1.94338929],
#        [ 1.86032896,  1.08191294],
#        [ 0.64392289,  1.48731358],
#        [ 0.90458134,  1.91805175],
#        [-0.92002776,  0.27111167],
#        [-1.09380006, -1.80656657],
#        [-0.83314161, -0.81840253],
#        [-1.1806862 ,  0.57516215],
#        [-0.74625547, -1.45184102],
#        [-0.92002776,  0.80320001],
#        [ 0.90458134,  1.3099508 ],
#        [ 0.2963783 , -0.51435205],
#        [-1.00691391, -0.2863142 ],
#        [ 2.20787355, -0.08361388],
#        [-0.83314161, -0.13428896],
#        [ 0.73080904, -0.00760126],
#        [ 1.59967052, -0.23563912],
#        [ 0.99146748,  0.70184985],
#        [-2.31020612,  1.51265111],
#        [-1.00691391,  1.00590032],
#        [-0.92002776, -0.08361388],
#        [-0.22493858,  0.42313691],
#        [ 1.33901207,  0.16976152],
#        [ 0.2963783 ,  0.11908644],
#        [ 1.16523978, -0.18496404],
#        [-0.22493858,  1.15792556],
#        [ 0.55703675, -0.08361388],
#        [-0.65936932, -0.33698928],
#        [ 1.77344281, -1.122453  ],
#        [ 0.12260601,  0.22043659],
#        [-1.3544585 , -2.05994197],
#        [-1.70200309, -0.59036467],
#        [-2.13643383,  2.7795281 ],
#        [-0.83314161, -1.52785364],
#        [-0.65936932,  0.22043659]])

# %%
x_train = scaler.fit_transform(x_train)

# %%
x_test = scaler.fit_transform(x_test)

# %%
x_test
# Out:
# array([[-1.11774654,  0.82956857],
#        [-1.11774654,  2.32707057],
#        [ 0.64166931, -0.71547318],
#        [ 0.53817426, -0.85809242],
#        [-0.91075644, -0.28761546],
#        [ 0.12419406, -0.24007572],
#        [ 1.15914456,  0.14024225],
#        [ 1.88360991,  0.54433009],
#        [-1.01425149, -0.28761546],
#        [-0.18629109, -1.45233924]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
clf.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = clf.predict(x_test)

# %%
y_pred
# Out:
# array([0, 0, 1, 1, 0, 1, 1, 1, 0, 0])

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, y_pred)
# Out:
# 1.0

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x_train, y_train.values, clf=clf, legend=2)
# Out:
# /Users/jomman/jupyter_envs/jupyter_venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/jomman/jupyter_envs/jupyter_venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/jomman/jupyter_envs/jupyter_venv/lib/python3.9/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# <Axes: >

# %%
df
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]

# %%
df.sample(5)
# Out:
#     cgpa     iq  placement
# 93   6.8  112.0          1
# 87   5.7  132.0          1
# 98   6.3  103.0          1
# 39   4.6  146.0          0
# 88   4.4  149.0          0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   cgpa       100 non-null    float64
#  1   iq         100 non-null    float64
#  2   placement  100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
df.isnull().sum()
# Out:
# cgpa         0
# iq           0
# placement    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.corr()
# Out:
#                cgpa        iq  placement
# cgpa       1.000000 -0.098791   0.821688
# iq        -0.098791  1.000000  -0.083031
# placement  0.821688 -0.083031   1.000000

# %%
df.corr()['cgpa']
# Out:
# cgpa         1.000000
# iq          -0.098791
# placement    0.821688
# Name: cgpa, dtype: float64

# %%
df.corr()['iq']
# Out:
# cgpa        -0.098791
# iq           1.000000
# placement   -0.083031
# Name: iq, dtype: float64

# %%
# %pip install seaborn
import seaborn as sns
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Users/jomman/jupyter_envs/jupyter_venv/lib/python3.9/site-packages (from seaborn) (2.0.2)
# Requirement already satisfied: pandas>=1.2 in /Users/jomman/jupyter_envs/jupyter_venv/lib/python3.9/site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Users/jomman/jupyter_envs/jupyter_venv/lib/python3.9/site-packages (from seaborn) (3.9.4)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/jomman/jupyter_envs/jupyter_venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/jomman/jupyter_envs/jupyter_venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/jomman/jupyter_envs/jupyter_venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.60.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/jomman/jupyter_envs/jupyter_venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /Users/jomman/jupyter_envs/jupyter_venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/jomman/jupyter_envs/jupyter_venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/jomman/jupyter_envs/jupyter_venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/jomman/jupyter_envs/jupyter_venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/jomman/jupyter_envs/jupyter_venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in /Users/jomman/jupyter_envs/jupyter_venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.23.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/jomman/jupyter_envs/jupyter_venv/lib/python3.9/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/jomman/jupyter_envs/jupyter_venv/lib/python3.9/site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in /Users/jomman/jupyter_envs/jupyter_venv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.
